# %% [markdown]
# <a href="https://colab.research.google.com/github/youssefhoffmann/A-star-Algorithm/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd 
from pandas_datareader import data
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
plt.style.use('fivethirtyeight')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
#load the data from Yahoo finance
start_date = '2015-01-09'
end_date = '2019-01-01'
ibm = data.DataReader('IBM', 'yahoo', start_date, end_date)
ibm.tail(10)
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2018-12-17  119.779999  115.070000  ...   7374500.0  108.190521
# 2018-12-18  118.230003  116.019997  ...   6290200.0  108.703064
# 2018-12-19  120.269997  115.970001  ...   6979800.0  108.498039
# 2018-12-20  116.449997  111.699997  ...   8454400.0  105.320343
# 2018-12-21  115.279999  110.440002  ...  10386500.0  103.382050
# 2018-12-24  111.000000  107.500000  ...   3821400.0  100.241623
# 2018-12-26  111.389999  105.940002  ...   6645800.0  103.801392
# 2018-12-27  113.779999  109.470001  ...   6045600.0  106.028572
# 2018-12-28  114.800003  112.500000  ...   5117500.0  105.329666
# 2018-12-31  114.349998  112.419998  ...   4982800.0  105.926056
#
# [10 rows x 6 columns]

# %%
#visualize the data
plt.figure(figsize=(12,5))
plt.plot(ibm['Adj Close'],label='IBM')
plt.xlabel('first of 2015 till the first of 2019')
plt.title('IBM adj Close price History')
plt.ylabel('Adj Close Price in $')
plt.legend(loc='upper right')
plt.show()

# %%
#Create a simple moving average with a 50 days window
SMA50=pd.DataFrame()
SMA50['Adj Close']=ibm['Adj Close'].rolling(window=50).mean()
SMA50
# Out:
#              Adj Close
# Date
# 2015-01-09         NaN
# 2015-01-12         NaN
# 2015-01-13         NaN
# 2015-01-14         NaN
# 2015-01-15         NaN
# ...                ...
# 2018-12-24  113.489210
# 2018-12-26  112.973163
# 2018-12-27  112.496507
# 2018-12-28  111.932445
# 2018-12-31  111.584033
#
# [1001 rows x 1 columns]

# %%
#Create a simple moving average of 100 days window
SMA100=pd.DataFrame()
SMA100['Adj Close']=ibm['Adj Close'].rolling(window=100).mean()
SMA100
# Out:
#              Adj Close
# Date
# 2015-01-09         NaN
# 2015-01-12         NaN
# 2015-01-13         NaN
# 2015-01-14         NaN
# 2015-01-15         NaN
# ...                ...
# 2018-12-24  124.421131
# 2018-12-26  124.157752
# 2018-12-27  123.873496
# 2018-12-28  123.597454
# 2018-12-31  123.318454
#
# [1001 rows x 1 columns]

# %%
#Visualize the data
plt.figure(figsize=(12,7))
plt.plot(ibm['Adj Close'],label='IBM')
plt.plot(SMA50['Adj Close'],label='SMA50')
plt.plot(SMA100['Adj Close'],label='SMA100')
plt.xlabel('first of 2015 till the first of 2019')
plt.title('IBM adj Close price History')
plt.ylabel('Adj Close Price in $')
plt.legend(loc='upper right')
plt.show()

# %%
#Create a new Dta frame to store all the data
new_data=pd.DataFrame()
new_data['IBM']=ibm['Adj Close']
new_data['SMA50']=SMA50['Adj Close']
new_data['SMA100']=SMA100['Adj Close']
new_data
# Out:
#                    IBM       SMA50      SMA100
# Date
# 2015-01-09  125.209694         NaN         NaN
# 2015-01-12  123.108620         NaN         NaN
# 2015-01-13  123.399734         NaN         NaN
# 2015-01-14  122.604950         NaN         NaN
# 2015-01-15  121.637016         NaN         NaN
# ...                ...         ...         ...
# 2018-12-24  100.241623  113.489210  124.421131
# 2018-12-26  103.801392  112.973163  124.157752
# 2018-12-27  106.028572  112.496507  123.873496
# 2018-12-28  105.329666  111.932445  123.597454
# 2018-12-31  105.926056  111.584033  123.318454
#
# [1001 rows x 3 columns]

# %%
#Create a function that determines when to buy and sell the stock or the commodity
def execute_order(new_data)
   sigBuy=[]
   sigSell=[]
   flag=0
   for i in range(len(new_data)):
     if new_data['SMA100'][i]>new_data['SMA50'][i]:
       if flag!=1
          sigBuy=sigBuy.append(new_data['IBM'][i])
          sigSell=sigSell.append(np.naan)
          flag=1
        else :
          sigSell=sigSell.append(np.naan)
          sigBuy=sigBuy.append(np.naan)
